# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.DataFrame([[1,2,3,4]],index=[0],columns=['hi','bue','kk','e'])
df_new=pd.Series([1,2,3,4,5,6])
pandasf=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/StudentsPerformance.csv")
pandasf['math score'].plot(kind='hist')
pandasf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
len(pandasf.value_counts())
# Out:
# 1000

# %%
# pandasf[pandasf['gender'].]

# %%
pandasf[pandasf['gender'].str.fullmatch('male')]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
pandasf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
pandasf['math score'].sum()
# Out:
# np.int64(66089)

# %%
pandasf['math_score updated']=pandasf['math score'].apply(lambda x: x+12 if x<40 else x+13 if x==40 else x+34)
pandasf.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
def categorize(column):
    return 'gay'

pandasf['gender']=pandasf.apply(categorize,axis=1)
pandasf
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      gay        group B           bachelor's degree      standard
# 1      gay        group C                some college      standard
# 2      gay        group B             master's degree      standard
# 3      gay        group A          associate's degree  free/reduced
# 4      gay        group C                some college      standard
# ..     ...            ...                         ...           ...
# 995    gay        group E             master's degree      standard
# 996    gay        group C                 high school  free/reduced
# 997    gay        group C                 high school  free/reduced
# 998    gay        group D                some college      standard
# 999    gay        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
eaf=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/archive/EAFC26-Men.csv")
eaf
# Out:
#            ID   Rank                   Name GENDER  OVR  PAC  SHO  PAS  DRI  \
# 0      209331      1          Mohamed Salah      M   91   89   88   86   90
# 1      231747      3          Kylian Mbappé      M   91   97   90   81   92
# 2      231443      5        Ousmane Dembélé      M   90   91   88   83   93
# 3      231866      6                  Rodri      M   90   65   80   86   84
# 4      203376      8        Virgil van Dijk      M   90   73   60   72   72
# ...       ...    ...                    ...    ...  ...  ...  ...  ...  ...
# 16223   70654  17869  Aaron Vanlalrinchhana      M   47   47   48   44   50
# 16224  275674  17870               Ma Haoqi      M   47   50   48   42   50
# 16225   76506  17871             Yu Zhuowei      M   47   57   46   37   46
# 16226  275659  17872              He Bizhen      M   47   60   23   29   31
# 16227  272761  17873           Lyu Jiaqiang      M   47   56   26   28   33
#
#        DEF  ...              League              Team  \
# ...

# %%
def genderapplier(row):
    if(pd.isnull(row['gender'])):
       return 'Moksha'
    return row['gender']
# def genderapplier(row):
#     if(row['gender'].isna):
#        return 'Moksha'
#     return row['gender']
    

a=pd.concat([pandasf,eaf])

b=a.apply(genderapplier,axis=1)
# a.interpolate()
b
# Out:
# 0           gay
# 1           gay
# 2           gay
# 3           gay
# 4           gay
#           ...
# 16223    Moksha
# 16224    Moksha
# 16225    Moksha
# 16226    Moksha
# 16227    Moksha
# Length: 17228, dtype: object

# %%
a['Team'].dropna()
# Out:
# 0               Liverpool
# 1             Real Madrid
# 2                Paris SG
# 3         Manchester City
# 4               Liverpool
#                ...
# 16223        Hyderabad FC
# 16224        Zhejiang Pro
# 16225       Dalian Yingbo
# 16226    Shanghai Shenhua
# 16227      Tianjin JMT FC
# Name: Team, Length: 16228, dtype: object

# %%
a.tail()
# Out:
#       gender race/ethnicity parental level of education lunch  \
# 16223    NaN            NaN                         NaN   NaN
# 16224    NaN            NaN                         NaN   NaN
# 16225    NaN            NaN                         NaN   NaN
# 16226    NaN            NaN                         NaN   NaN
# 16227    NaN            NaN                         NaN   NaN
#
#       test preparation course  math score  reading score  writing score  \
# 16223                     NaN         NaN            NaN            NaN
# 16224                     NaN         NaN            NaN            NaN
# 16225                     NaN         NaN            NaN            NaN
# 16226                     NaN         NaN            NaN            NaN
# 16227                     NaN         NaN            NaN            NaN
#
#        math_score updated        ID  ...  League              Team play style  \
# ...

# %%
a[a['race/ethnicity'].isnull()]
# Out:
#       gender race/ethnicity parental level of education lunch  \
# 0        NaN            NaN                         NaN   NaN
# 1        NaN            NaN                         NaN   NaN
# 2        NaN            NaN                         NaN   NaN
# 3        NaN            NaN                         NaN   NaN
# 4        NaN            NaN                         NaN   NaN
# ...      ...            ...                         ...   ...
# 16223    NaN            NaN                         NaN   NaN
# 16224    NaN            NaN                         NaN   NaN
# 16225    NaN            NaN                         NaN   NaN
# 16226    NaN            NaN                         NaN   NaN
# 16227    NaN            NaN                         NaN   NaN
#
#       test preparation course  math score  reading score  writing score  \
# 0                         NaN         NaN            NaN            NaN
# 1                         NaN         NaN            NaN            NaN
# ...

# %%
pandasf['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
pandasf.groupby('gender')['math score'].sum()
# Out:
# gender
# gay    66089
# Name: math score, dtype: int64

# %%
import pandas as pd
gym=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/archive (2)/Gym_Progress_Dataset.csv")
gym['date']=pd.to_datetime(gym['Day'])
gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Day                   200 non-null    object
#  1   Weight_kg             200 non-null    float64
#  2   Calories_Intake       200 non-null    int64
#  3   Protein_Intake_g      200 non-null    int64
#  4   Workout_Duration_min  200 non-null    int64
#  5   Steps_Walked          200 non-null    int64
#  6   date                  200 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 11.1+ KB

# %%
pandasf
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      gay        group B           bachelor's degree      standard
# 1      gay        group C                some college      standard
# 2      gay        group B             master's degree      standard
# 3      gay        group A          associate's degree  free/reduced
# 4      gay        group C                some college      standard
# ..     ...            ...                         ...           ...
# 995    gay        group E             master's degree      standard
# 996    gay        group C                 high school  free/reduced
# 997    gay        group C                 high school  free/reduced
# 998    gay        group D                some college      standard
# 999    gay        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
eaf=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/archive/EAFC26-Men.csv")
eaf
# Out:
#            ID   Rank                   Name GENDER  OVR  PAC  SHO  PAS  DRI  \
# 0      209331      1          Mohamed Salah      M   91   89   88   86   90
# 1      231747      3          Kylian Mbappé      M   91   97   90   81   92
# 2      231443      5        Ousmane Dembélé      M   90   91   88   83   93
# 3      231866      6                  Rodri      M   90   65   80   86   84
# 4      203376      8        Virgil van Dijk      M   90   73   60   72   72
# ...       ...    ...                    ...    ...  ...  ...  ...  ...  ...
# 16223   70654  17869  Aaron Vanlalrinchhana      M   47   47   48   44   50
# 16224  275674  17870               Ma Haoqi      M   47   50   48   42   50
# 16225   76506  17871             Yu Zhuowei      M   47   57   46   37   46
# 16226  275659  17872              He Bizhen      M   47   60   23   29   31
# 16227  272761  17873           Lyu Jiaqiang      M   47   56   26   28   33
#
#        DEF  ...              League              Team  \
# ...

# %%
eaf.groupby(['League','Team']).apply(lambda df:df.loc[df['Rank'].idxmax()])
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\3336758746.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   eaf.groupby(['League','Team']).apply(lambda df:df.loc[df['Rank'].idxmax()])
#                                   ID   Rank                     Name GENDER  \
# League        Team
# 1A Pro League Cercle Brugge    79828  17605           Ibrahima Diaby      M
#               Club Brugge      70975  15289  Bi Abdoul Kader Yameogo      M
#               FCV Dender EH    80125  17089             Ryan Adewusi      M
#               KAA Gent         80126  15958      Mohammed El Âdfaoui      M
#               KRC Genk        262099  16128            Kayden Pierre      M
# ...

# %%
eaf.groupby(['League','Team']).apply(lambda df:df)
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\3944001127.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   eaf.groupby(['League','Team']).apply(lambda df:df)
#                                         ID   Rank                    Name  \
# League        Team
# 1A Pro League Cercle Brugge  3252   277178   4190           Oumar Diakité
#                              4282   251537   5355             Gary Magnée
#                              4331   263397   5405              Alan Minda
#                              4520   201438   5627  Hannes Van Der Bruggen
#                              4574   255754   5682                Warleson
# ...

# %%
gym=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/archive (2)/Gym_Progress_Dataset.csv")
gym
# Out:
#             Day  Weight_kg  Calories_Intake  Protein_Intake_g  \
# 0    2025-01-01       71.5             3209                70
# 1    2025-01-02       69.6             2584               150
# 2    2025-01-03       71.9             2927               148
# 3    2025-01-04       74.6             3216                85
# 4    2025-01-05       69.3             2045               145
# ..          ...        ...              ...               ...
# 195  2025-07-15       71.2             3316               100
# 196  2025-07-16       67.3             2898                70
# 197  2025-07-17       70.5             2212                54
# 198  2025-07-18       70.2             3199               141
# 199  2025-07-19       66.6             3243               110
#
#      Workout_Duration_min  Steps_Walked
# 0                      41          6820
# 1                      40          4898
# 2                      89          9546
# 3                      20          2077
# ...

# %%
gym['Day']=pd.to_datetime(gym['Day'])
gym['year']=gym['Day'].dt.year
gym['year'].value_counts()
# Out:
# year
# 2025    200
# Name: count, dtype: int64

# %%
pandasf['first']=pandasf['parental level of education'].str.split(' ').str[0]
pandasf
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0      gay        group B           bachelor's degree      standard
# 1      gay        group C                some college      standard
# 2      gay        group B             master's degree      standard
# 3      gay        group A          associate's degree  free/reduced
# 4      gay        group C                some college      standard
# ..     ...            ...                         ...           ...
# 995    gay        group E             master's degree      standard
# 996    gay        group C                 high school  free/reduced
# 997    gay        group C                 high school  free/reduced
# 998    gay        group D                some college      standard
# 999    gay        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
bios=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/bios.csv")
bios['year']=bios['Born'].str.split(" ").str[2]
bios['month'] = bios['Born'].str.extract(
    r'(\d{1,2}\s+(January|February|March|April|May|June|July|August|September|October|November|December))'
)[0]

bios
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# ...

# %%
plt.scatter(pandasf["math score"],pandasf['reading score'],alpha=0.2)
plt.xlabel("math score")
plt.ylabel('reading score')
plt.title("hello")
plt.grid()

# %%
bios[['height','weight']]=bios['Measurements'].str.split('/',expand=True)
bios['height']=bios['height'].str[0:-3]
bios=bios.loc[pd.notnull(bios['height'])]
bios['height'] = pd.to_numeric(bios['height'], errors='coerce')
bios['height'] = bios['height'].astype('Int64')
# bios['month']=bios['month'].str.split(" ").str[1]
# bios['month']=bios['month'].astype('str')
# bios['MONTH']=bios['month'].str.split(" ").str[1]
bios['month']=bios['month'].astype('string')
bios['Month']=bios['month'].str.split(" ").str[1]
bios
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\3390463386.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios['height'] = pd.to_numeric(bios['height'], errors='coerce')
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\3390463386.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios['height'] = bios['height'].astype('Int64')
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\3390463386.py:9: SettingWithCopyWarning:
# ...

# %%
bios['Month']=bios['Month'].fillna("Vansh")
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\1336507738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios['Month']=bios['Month'].fillna("Vansh")

# %%
plt.scatter(bios['height'],bios['Month'])

# %%
bios['Month'].value_counts()
# Out:
# Month
# January      10182
# March         9682
# May           9276
# April         9152
# February      9030
# September     8874
# July          8857
# August        8720
# June          8682
# October       8464
# December      8256
# November      8024
# Vansh          634
# Name: count, dtype: int64

# %%
netflix=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/netflix_titles.csv/netflix_titles.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dates_2021=netflix.loc[netflix['date_added'].str.contains('2021') & pd.notnull(netflix['date_added'])]
dates_2021
# Out:
#      show_id     type                                           title  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 1         s2  TV Show                                   Blood & Water
# 2         s3  TV Show                                       Ganglands
# 3         s4  TV Show                           Jailbirds New Orleans
# 4         s5  TV Show                                    Kota Factory
# ...      ...      ...                                             ...
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8437   s8438  TV Show                          The Netflix Afterparty
# 8461   s8462    Movie                               The Polar Express
#
#              director                                               cast  \
# ...

# %%
# x = dates_2021['release_year']
# x_centered = x - x.mean()
# plt.plot(x_centered,x_centered**2)
dates_2021['Month']=dates_2021["date_added"].str.extract(r'^(January|February|March|April|May|June|July|August|September|October|November|December)')
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_42700\1605917817.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates_2021['Month']=dates_2021["date_added"].str.extract(r'^(January|February|March|April|May|June|July|August|September|October|November|December)')

# %%
dates_2021
# Out:
#      show_id     type                                           title  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 1         s2  TV Show                                   Blood & Water
# 2         s3  TV Show                                       Ganglands
# 3         s4  TV Show                           Jailbirds New Orleans
# 4         s5  TV Show                                    Kota Factory
# ...      ...      ...                                             ...
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8437   s8438  TV Show                          The Netflix Afterparty
# 8461   s8462    Movie                               The Polar Express
#
#              director                                               cast  \
# ...

# %%
ffg=dates_2021.groupby('Month').size().reset_index().rename(columns={0:'numberofelements'})
plt.bar(ffg['Month'],ffg['numberofelements'])
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'April'),
#   Text(1, 0, 'August'),
#   Text(2, 0, 'February'),
#   Text(3, 0, 'January'),
#   Text(4, 0, 'July'),
#   Text(5, 0, 'June'),
#   Text(6, 0, 'March'),
#   Text(7, 0, 'May'),
#   Text(8, 0, 'September')])

# %%
salary=pd.read_csv("C:/Users/VANSH TIBREWAL/Downloads/archive (3)/Experience-Salary.csv")
exp=salary.iloc[:,0:1]
income=salary.iloc[:,-1]
plt.scatter(exp,income)
exp
# Out:
#      exp(in months)
# 0         18.290293
# 1         17.023407
# 2         26.343613
# 3         19.105834
# 4         27.742516
# ..              ...
# 995       22.161741
# 996       32.266497
# 997       17.039030
# 998       25.222124
# 999       16.418028
#
# [1000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
x_train,x_test,y_train,y_test=train_test_split(exp,income,train_size=0.2,random_state=2)
x_train.shape
x_test.shape
# Out:
# (800, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# x_test.iloc[0]

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([29.66726668])

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([29.66726668, 21.63759196, 40.02296139, 36.76799308, 24.06135868,
#        28.09943285, 34.4449154 , 21.89790541, 27.03896385, 21.08882815,
#         7.15366254, 28.31305302, 28.70038209, 23.31781401, 40.24940529,
#        21.95163042, 19.9110214 , 18.33259726, 25.84768022, 21.23362061,
#        32.95787258, 30.88999333,  9.47226684, 26.42063168, 23.64348844,
#        11.53896725, 39.1421719 , 18.94705121, 23.14698881, 24.34330483,
#        33.44408219, 25.71797223, 30.46420369, 32.5404188 , 23.7150373 ,
#        20.85860665, 26.10188482, 39.52280959, 15.77050298, 27.9370612 ,
#        20.53422314, 22.52995349, 35.51790441, 42.1986281 , 18.78457706,
#        31.37943349, 38.94289503, 25.5654928 , 18.34888656, 30.99108653,
#        35.80213817, 19.97127247, 22.86652538, 32.9066502 , 29.48636351,
#        41.68969476, 35.6550728 , 21.21312001, 25.54691219, 25.56707471,
#        15.50329555, 21.60138798, 13.81482319, 21.20469068, 23.03527856,
# ...

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error,r2_score
mean_absolute_error(y_pred=y_predict,y_true=y_test)
# Out:
# 4.050525025985646

# %%
r2=r2_score(y_true=y_test,y_pred=y_predict)
r2
# Out:
# 0.6606759475251437

# %%
n=len(x_test)
k=x_test.shape[1]

adjusted_r2=1-((1-r2)*(n-1)/(n-1-k))
adjusted_r2
# Out:
# 0.660250729414273

# %%
salary.loc[salary["exp(in months)"]==x_test.iloc[0].values[0]]
# Out:
#     exp(in months)  salary(in thousands)
# 37       29.782025             31.891582

# %%
plt.plot(x_test,lr.predict(x_test),c="red")
plt.scatter(exp,income)

# %%
import seaborn as sns
residue=y_test-lr.predict(x_test)
sns.displot(residue,kind='kde')

# %%
# to check homoscenecity

plt.scatter(lr.predict(x_test),residue)

# %%
plt.plot(residue)

# %%
#only one feature so not useful and not work

# from statsmodels.stats.outliers_influence import variance_inflation_factor
# vara=[]
# for i in range(1):
#     vara.append(variance_inflation_factor(x_train,i))
# vara
# Out:
# []

# %%
lr.predict(np.array([23.4]).reshape(1,-1))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24.186195])

# %%
class Meralr:
    def __init__(self):
        self.m=None
        self.b=None
    def fit(self,x_train,y_train):
        num=0
        dum=0
        for i in range(x_train.shape[0]):
            num+=(x_train[i]-x_train.mean())*(y_train[i]-y_train.mean())
            dum+=(x_train[i]-x_train.mean())**2
        self.m=num/dum
        self.b=y_train.mean()-self.m*(x_train.mean())
    def predict(self,x_test):
        return self.m*x_test+self.b

# %%
from sklearn.model_selection import train_test_split
x=salary['exp(in months)'].values
y=salary['salary(in thousands)'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,train_size=0.2)
lr=Meralr()
lr.fit(x_train,y_train)
lr.predict(x_test[0])
# Out:
# np.float64(29.667266684483156)

# %%
a=np.random.randint(low=0,high=660,size=(200,))
b=np.random.random(size=(200,))
plt.scatter(a,b)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

X_TRAIN,X_TEST,Y_TRAIN,Y_TEST=train_test_split(a,b,random_state=2,train_size=0.1)
lrr=LinearRegression()
lrr.fit(X_TRAIN.reshape(-1,1),Y_TRAIN)
lrr.predict(X_TEST.reshape(-1,1))
plt.plot(X_TEST,lrr.predict(X_TEST.reshape(-1,1)))
plt.scatter(a,b)
r2_score(y_true=Y_TEST,y_pred=lrr.predict(X_TEST.reshape(-1,1)))
# Out:
# -0.056661060331908875

# %%
residue2=Y_TEST-lrr.predict(X_TEST.reshape(-1,1))
sns.displot(residue2,kind='kde')

# %%
plt.plot(residue2)

# %%
from sklearn import datasets
data=datasets.load_diabetes()
list=[]
for i in range(len(data.data)):
    list.append(data.data[i][8])

plt.scatter(list,data.target)
# len(data.target)

# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml("leukemia", version=1, return_X_y=True)
print(X.shape)
# Out:
# (72, 7129)

# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml("leukemia", version=1, return_X_y=True)
print(y)
# Out:
# 0     ALL
# 1     ALL
# 2     ALL
# 3     ALL
# 4     ALL
#      ...
# 67    ALL
# 68    ALL
# 69    ALL
# 70    ALL
# 71    ALL
# Name: CLASS, Length: 72, dtype: category
# Categories (2, object): ['ALL', 'AML']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.datasets import load_iris
X,y=load_iris(return_X_y=True)
data=load_iris()
features=data.feature_names

vari=[]
for i in range(X.shape[1]):
    vari.append(variance_inflation_factor(X,i))
vari=pd.DataFrame(data=vari,index=features).T
vari
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0         262.969348         96.353292         172.960962          55.50206
