# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('synthetic_dataset.csv')
# df.drop(columns=['Category','Stock'])

# %%
df.isnull().mean()*100
# Out:
# Category    62.998624
# Price        3.988996
# Rating      46.996790
# Stock       30.994956
# Discount     8.986703
# dtype: float64

# %%
df_new=df.loc[~df['Price'].isnull()]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df_new['Price'].plot.density(ax=axes[0], title='New Price')
df['Price'].plot.density(ax=axes[1], title='Original Price')


# df_new['Price'].plot.density(label='new')
# df['Price'].plot.density(label='original')
# Out:
# <Axes: title={'center': 'Original Price'}, ylabel='Density'>

# %% [markdown]
# <h2>We can see both distribution are same</h2>

# %%
df_second=df[~df['Discount'].isnull()]

# %%
df_second['Discount'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Discount'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# so we can drop columns 
columns_we_can_drop_safely=['Price','Discount']  # we can safely remove nan rows in this columns

# %%
cat=pd.read_csv("C:/Users/VANSH TIBREWAL/Desktop/Datasets/all_anonymized_2015_11_2017_03.csv")
cat
# Out:
# C:\Users\VANSH TIBREWAL\AppData\Local\Temp\ipykernel_15772\2046664150.py:1: DtypeWarning: Columns (7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   cat=pd.read_csv("C:/Users/VANSH TIBREWAL/Desktop/Datasets/all_anonymized_2015_11_2017_03.csv")
#                  maker     model   mileage  manufacture_year  \
# 0                 ford    galaxy  151000.0            2011.0
# 1                skoda   octavia  143476.0            2012.0
# 2                  bmw       NaN   97676.0            2010.0
# 3                skoda     fabia  111970.0            2004.0
# 4                skoda     fabia  128886.0            2004.0
# ...                ...       ...       ...               ...
# 3552907          skoda  roomster   54000.0            2013.0
# 3552908          skoda   felicia       NaN            2000.0
# 3552909          skoda   octavia  230000.0            2006.0
# 3552910          skoda     fabia       NaN            2001.0
# ...

# %%
cat.isnull().mean()*100
# Out:
# maker                  14.605343
# model                  31.899495
# mileage                10.205263
# manufacture_year       10.430261
# engine_displacement    20.924076
# engine_power           15.617527
# body_type              31.605455
# color_slug             94.103400
# stk_year               84.910828
# transmission           20.873863
# door_count             30.680918
# seat_count             36.226594
# fuel_type              52.002583
# date_created            0.000000
# date_last_seen          0.000000
# price_eur               0.000000
# dtype: float64

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552912 entries, 0 to 3552911
# Data columns (total 16 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   maker                object
#  1   model                object
#  2   mileage              float64
#  3   manufacture_year     float64
#  4   engine_displacement  float64
#  5   engine_power         float64
#  6   body_type            object
#  7   color_slug           object
#  8   stk_year             float64
#  9   transmission         object
#  10  door_count           float64
#  11  seat_count           float64
#  12  fuel_type            object
#  13  date_created         object
#  14  date_last_seen       object
#  15  price_eur            float64
# dtypes: float64(8), object(8)
# memory usage: 433.7+ MB

# %%
cat = cat.drop(columns=cat.select_dtypes(include=['float64']).columns)

# %%
cat
# Out:
#                  maker     model body_type color_slug transmission fuel_type  \
# 0                 ford    galaxy       NaN        NaN          man    diesel
# 1                skoda   octavia       NaN        NaN          man    diesel
# 2                  bmw       NaN       NaN        NaN          man    diesel
# 3                skoda     fabia       NaN        NaN          man  gasoline
# 4                skoda     fabia       NaN        NaN          man  gasoline
# ...                ...       ...       ...        ...          ...       ...
# 3552907          skoda  roomster     other        NaN          NaN       NaN
# 3552908          skoda   felicia     other        NaN          NaN  electric
# 3552909          skoda   octavia     other        NaN          NaN       NaN
# 3552910          skoda     fabia     other        NaN          NaN       NaN
# 3552911  mercedes-benz       NaN     other        NaN          NaN       NaN
#
# ...

# %% [markdown]
# <h1>Filling up maker column with skoda so that missing percentage reduce below 5% so that CCA works fine </h1>

# %%
index=cat[cat['maker'].isnull()].index
index=index.to_numpy().copy()

# %%
np.random.shuffle(index)
index=index[:(int)(0.9*len(index))]
index
# Out:
# array([1466338,  100682,  998882, ..., 1063494,  316353,  335541])

# %%
cat.loc[index,'maker']='skoda'

# %%
cat.isnull().mean()*100
# Out:
# maker              2.775048
# model             31.899495
# body_type         31.605455
# color_slug        94.103400
# transmission      20.873863
# fuel_type         52.002583
# date_created       0.000000
# date_last_seen     0.000000
# dtype: float64

# %%
cat_new=cat[~cat['maker'].isnull()]

# %%
df1=cat['maker'].value_counts()/len(cat['maker'])
df2=cat_new['maker'].value_counts()/len(cat_new['maker'])
pd.concat([df1,df2],axis=1)
# Out:
#                   count     count
# maker
# skoda          0.206633  0.212531
# volkswagen     0.083665  0.086053
# bmw            0.075074  0.077217
# mercedes-benz  0.070918  0.072942
# audi           0.069971  0.071968
# ford           0.067707  0.069639
# opel           0.061276  0.063025
# fiat           0.037341  0.038407
# citroen        0.034314  0.035293
# renault        0.030069  0.030927
# peugeot        0.025931  0.026671
# hyundai        0.022686  0.023334
# seat           0.021010  0.021609
# toyota         0.020521  0.021106
# nissan         0.019141  0.019688
# kia            0.013681  0.014071
# volvo          0.013586  0.013974
# mazda          0.012853  0.013220
# mini           0.010042  0.010329
# smart          0.009265  0.009530
# suzuki         0.008777  0.009028
# mitsubishi     0.008011  0.008240
# honda          0.007381  0.007592
# porsche        0.006844  0.007040
# chevrolet      0.005870  0.006038
# rover          0.005801  0.005967
# ...

# %% [markdown]
# <h1>Hence the data cleaning is good here since distribution doesnt change and misssing data was  less than 5%</h1>
